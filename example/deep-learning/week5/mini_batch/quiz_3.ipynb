# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import numpy as np
# from helper import batches  # Helper function created in Mini-batching section

def batches(batch_size, features, labels):
    """
    Create batches of features and labels
    :param batch_size: The batch size
    :param features: List of features
    :param labels: List of labels
    :return: Batches of (Features, Labels)
    """
    assert len(features) == len(labels)
    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0, sample_size, batch_size):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i], labels[start_i:end_i]]
        outout_batches.append(batch)
        
    return outout_batches


def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('datasets/ud730/mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

init = tf.global_variables_initializer()

batch_size = 128
epochs = 200
learn_rate = 0.01

train_batches = batches(batch_size, train_features, train_labels)

with tf.Session() as sess:
    sess.run(init)

    # Training cycle
    for epoch_i in range(epochs):

        # Loop over all batches
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)

        # Print cost and validation accuracy of an epoch
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: test_features, labels: test_labels})

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Extracting datasets/ud730/mnist/train-images-idx3-ubyte.gz
# Extracting datasets/ud730/mnist/train-labels-idx1-ubyte.gz
# Extracting datasets/ud730/mnist/t10k-images-idx3-ubyte.gz
# Extracting datasets/ud730/mnist/t10k-labels-idx1-ubyte.gz
# Epoch: 0    - Cost: 5.78     Valid Accuracy: 0.271
# Epoch: 1    - Cost: 4.04     Valid Accuracy: 0.406
# Epoch: 2    - Cost: 3.16     Valid Accuracy: 0.505
# Epoch: 3    - Cost: 2.63     Valid Accuracy: 0.568
# Epoch: 4    - Cost: 2.26     Valid Accuracy: 0.614
# Epoch: 5    - Cost: 1.99     Valid Accuracy: 0.648
# Epoch: 6    - Cost: 1.78     Valid Accuracy: 0.674
# Epoch: 7    - Cost: 1.61     Valid Accuracy: 0.697
# Epoch: 8    - Cost: 1.47     Valid Accuracy: 0.717
# Epoch: 9    - Cost: 1.36     Valid Accuracy: 0.731
# Epoch: 10   - Cost: 1.26     Valid Accuracy: 0.742
# Epoch: 11   - Cost: 1.19     Valid Accuracy: 0.754
# Epoch: 12   - Cost: 1.13     Valid Accuracy: 0.76
# Epoch: 13   - Cost: 1.08     Valid Accuracy: 0.767
# Epoch: 14   - Cost: 1.03     Valid Accuracy: 0.776
# Epoch: 15   - Cost: 0.993    Valid Accuracy: 0.782
# Epoch: 16   - Cost: 0.96     Valid Accuracy: 0.787
# Epoch: 17   - Cost: 0.93     Valid Accuracy: 0.791
# Epoch: 18   - Cost: 0.904    Valid Accuracy: 0.794
# Epoch: 19   - Cost: 0.881    Valid Accuracy: 0.799
# Epoch: 20   - Cost: 0.86     Valid Accuracy: 0.803
# Epoch: 21   - Cost: 0.841    Valid Accuracy: 0.807
# Epoch: 22   - Cost: 0.824    Valid Accuracy: 0.809
# Epoch: 23   - Cost: 0.808    Valid Accuracy: 0.813
# Epoch: 24   - Cost: 0.794    Valid Accuracy: 0.815
# Epoch: 25   - Cost: 0.78     Valid Accuracy: 0.817
# Epoch: 26   - Cost: 0.768    Valid Accuracy: 0.819
# Epoch: 27   - Cost: 0.756    Valid Accuracy: 0.82
# Epoch: 28   - Cost: 0.745    Valid Accuracy: 0.821
# Epoch: 29   - Cost: 0.735    Valid Accuracy: 0.823
# Epoch: 30   - Cost: 0.726    Valid Accuracy: 0.826
# Epoch: 31   - Cost: 0.717    Valid Accuracy: 0.827
# Epoch: 32   - Cost: 0.708    Valid Accuracy: 0.829
# Epoch: 33   - Cost: 0.7      Valid Accuracy: 0.829
# Epoch: 34   - Cost: 0.692    Valid Accuracy: 0.831
# Epoch: 35   - Cost: 0.685    Valid Accuracy: 0.833
# Epoch: 36   - Cost: 0.678    Valid Accuracy: 0.835
# Epoch: 37   - Cost: 0.671    Valid Accuracy: 0.837
# Epoch: 38   - Cost: 0.665    Valid Accuracy: 0.839
# Epoch: 39   - Cost: 0.658    Valid Accuracy: 0.841
# Epoch: 40   - Cost: 0.652    Valid Accuracy: 0.841
# Epoch: 41   - Cost: 0.647    Valid Accuracy: 0.842
# Epoch: 42   - Cost: 0.641    Valid Accuracy: 0.843
# Epoch: 43   - Cost: 0.636    Valid Accuracy: 0.844
# Epoch: 44   - Cost: 0.631    Valid Accuracy: 0.845
# Epoch: 45   - Cost: 0.626    Valid Accuracy: 0.847
# Epoch: 46   - Cost: 0.621    Valid Accuracy: 0.847
# Epoch: 47   - Cost: 0.616    Valid Accuracy: 0.849
# Epoch: 48   - Cost: 0.612    Valid Accuracy: 0.849
# Epoch: 49   - Cost: 0.607    Valid Accuracy: 0.85
# Epoch: 50   - Cost: 0.603    Valid Accuracy: 0.85
# Epoch: 51   - Cost: 0.599    Valid Accuracy: 0.851
# Epoch: 52   - Cost: 0.595    Valid Accuracy: 0.852
# Epoch: 53   - Cost: 0.591    Valid Accuracy: 0.852
# Epoch: 54   - Cost: 0.587    Valid Accuracy: 0.853
# Epoch: 55   - Cost: 0.583    Valid Accuracy: 0.854
# Epoch: 56   - Cost: 0.58     Valid Accuracy: 0.855
# Epoch: 57   - Cost: 0.576    Valid Accuracy: 0.855
# Epoch: 58   - Cost: 0.572    Valid Accuracy: 0.856
# Epoch: 59   - Cost: 0.569    Valid Accuracy: 0.856
# Epoch: 60   - Cost: 0.566    Valid Accuracy: 0.857
# Epoch: 61   - Cost: 0.562    Valid Accuracy: 0.858
# Epoch: 62   - Cost: 0.559    Valid Accuracy: 0.858
# Epoch: 63   - Cost: 0.556    Valid Accuracy: 0.859
# Epoch: 64   - Cost: 0.553    Valid Accuracy: 0.86
# Epoch: 65   - Cost: 0.55     Valid Accuracy: 0.861
# Epoch: 66   - Cost: 0.547    Valid Accuracy: 0.861
# Epoch: 67   - Cost: 0.544    Valid Accuracy: 0.862
# Epoch: 68   - Cost: 0.541    Valid Accuracy: 0.863
# Epoch: 69   - Cost: 0.538    Valid Accuracy: 0.863
# Epoch: 70   - Cost: 0.536    Valid Accuracy: 0.864
# Epoch: 71   - Cost: 0.533    Valid Accuracy: 0.865
# Epoch: 72   - Cost: 0.53     Valid Accuracy: 0.866
# Epoch: 73   - Cost: 0.528    Valid Accuracy: 0.866
# Epoch: 74   - Cost: 0.525    Valid Accuracy: 0.866
# Epoch: 75   - Cost: 0.523    Valid Accuracy: 0.867
# Epoch: 76   - Cost: 0.52     Valid Accuracy: 0.868
# Epoch: 77   - Cost: 0.518    Valid Accuracy: 0.869
# Epoch: 78   - Cost: 0.516    Valid Accuracy: 0.869
# Epoch: 79   - Cost: 0.513    Valid Accuracy: 0.869
# Epoch: 80   - Cost: 0.511    Valid Accuracy: 0.87
# Epoch: 81   - Cost: 0.509    Valid Accuracy: 0.872
# Epoch: 82   - Cost: 0.507    Valid Accuracy: 0.872
# Epoch: 83   - Cost: 0.504    Valid Accuracy: 0.872
# Epoch: 84   - Cost: 0.502    Valid Accuracy: 0.873
# Epoch: 85   - Cost: 0.5      Valid Accuracy: 0.874
# Epoch: 86   - Cost: 0.498    Valid Accuracy: 0.874
# Epoch: 87   - Cost: 0.496    Valid Accuracy: 0.875
# Epoch: 88   - Cost: 0.494    Valid Accuracy: 0.875
# Epoch: 89   - Cost: 0.492    Valid Accuracy: 0.876
# Epoch: 90   - Cost: 0.49     Valid Accuracy: 0.876
# Epoch: 91   - Cost: 0.488    Valid Accuracy: 0.876
# Epoch: 92   - Cost: 0.486    Valid Accuracy: 0.877
# Epoch: 93   - Cost: 0.484    Valid Accuracy: 0.878
# Epoch: 94   - Cost: 0.482    Valid Accuracy: 0.879
# Epoch: 95   - Cost: 0.481    Valid Accuracy: 0.879
# Epoch: 96   - Cost: 0.479    Valid Accuracy: 0.879
# Epoch: 97   - Cost: 0.477    Valid Accuracy: 0.879
# Epoch: 98   - Cost: 0.475    Valid Accuracy: 0.879
# Epoch: 99   - Cost: 0.473    Valid Accuracy: 0.88
# Epoch: 100  - Cost: 0.472    Valid Accuracy: 0.88
# Epoch: 101  - Cost: 0.47     Valid Accuracy: 0.879
# Epoch: 102  - Cost: 0.468    Valid Accuracy: 0.88
# Epoch: 103  - Cost: 0.467    Valid Accuracy: 0.88
# Epoch: 104  - Cost: 0.465    Valid Accuracy: 0.88
# Epoch: 105  - Cost: 0.463    Valid Accuracy: 0.88
# Epoch: 106  - Cost: 0.462    Valid Accuracy: 0.88
# Epoch: 107  - Cost: 0.46     Valid Accuracy: 0.881
# Epoch: 108  - Cost: 0.459    Valid Accuracy: 0.881
# Epoch: 109  - Cost: 0.457    Valid Accuracy: 0.881
# Epoch: 110  - Cost: 0.456    Valid Accuracy: 0.882
# Epoch: 111  - Cost: 0.454    Valid Accuracy: 0.882
# Epoch: 112  - Cost: 0.453    Valid Accuracy: 0.882
# Epoch: 113  - Cost: 0.451    Valid Accuracy: 0.882
# Epoch: 114  - Cost: 0.45     Valid Accuracy: 0.883
# Epoch: 115  - Cost: 0.448    Valid Accuracy: 0.883
# Epoch: 116  - Cost: 0.447    Valid Accuracy: 0.883
# Epoch: 117  - Cost: 0.445    Valid Accuracy: 0.884
# Epoch: 118  - Cost: 0.444    Valid Accuracy: 0.884
# Epoch: 119  - Cost: 0.443    Valid Accuracy: 0.884
# Epoch: 120  - Cost: 0.441    Valid Accuracy: 0.884
# Epoch: 121  - Cost: 0.44     Valid Accuracy: 0.885
# Epoch: 122  - Cost: 0.439    Valid Accuracy: 0.885
# Epoch: 123  - Cost: 0.437    Valid Accuracy: 0.885
# Epoch: 124  - Cost: 0.436    Valid Accuracy: 0.885
# Epoch: 125  - Cost: 0.435    Valid Accuracy: 0.886
# Epoch: 126  - Cost: 0.433    Valid Accuracy: 0.886
# Epoch: 127  - Cost: 0.432    Valid Accuracy: 0.886
# Epoch: 128  - Cost: 0.431    Valid Accuracy: 0.886
# Epoch: 129  - Cost: 0.43     Valid Accuracy: 0.886
# Epoch: 130  - Cost: 0.428    Valid Accuracy: 0.886
# Epoch: 131  - Cost: 0.427    Valid Accuracy: 0.886
# Epoch: 132  - Cost: 0.426    Valid Accuracy: 0.886
# Epoch: 133  - Cost: 0.425    Valid Accuracy: 0.886
# Epoch: 134  - Cost: 0.424    Valid Accuracy: 0.887
# Epoch: 135  - Cost: 0.423    Valid Accuracy: 0.887
# Epoch: 136  - Cost: 0.421    Valid Accuracy: 0.887
# Epoch: 137  - Cost: 0.42     Valid Accuracy: 0.887
# Epoch: 138  - Cost: 0.419    Valid Accuracy: 0.887
# Epoch: 139  - Cost: 0.418    Valid Accuracy: 0.887
# Epoch: 140  - Cost: 0.417    Valid Accuracy: 0.888
# Epoch: 141  - Cost: 0.416    Valid Accuracy: 0.888
# Epoch: 142  - Cost: 0.415    Valid Accuracy: 0.888
# Epoch: 143  - Cost: 0.414    Valid Accuracy: 0.888
# Epoch: 144  - Cost: 0.413    Valid Accuracy: 0.888
# Epoch: 145  - Cost: 0.412    Valid Accuracy: 0.889
# Epoch: 146  - Cost: 0.411    Valid Accuracy: 0.889
# Epoch: 147  - Cost: 0.41     Valid Accuracy: 0.889
# Epoch: 148  - Cost: 0.409    Valid Accuracy: 0.889
# Epoch: 149  - Cost: 0.408    Valid Accuracy: 0.889
# Epoch: 150  - Cost: 0.407    Valid Accuracy: 0.889
# Epoch: 151  - Cost: 0.406    Valid Accuracy: 0.889
# Epoch: 152  - Cost: 0.405    Valid Accuracy: 0.89
# Epoch: 153  - Cost: 0.404    Valid Accuracy: 0.89
# Epoch: 154  - Cost: 0.403    Valid Accuracy: 0.889
# Epoch: 155  - Cost: 0.402    Valid Accuracy: 0.889
# Epoch: 156  - Cost: 0.401    Valid Accuracy: 0.889
# Epoch: 157  - Cost: 0.4      Valid Accuracy: 0.889
# Epoch: 158  - Cost: 0.399    Valid Accuracy: 0.89
# Epoch: 159  - Cost: 0.398    Valid Accuracy: 0.89
# Epoch: 160  - Cost: 0.397    Valid Accuracy: 0.89
# Epoch: 161  - Cost: 0.396    Valid Accuracy: 0.89
# Epoch: 162  - Cost: 0.395    Valid Accuracy: 0.89
# Epoch: 163  - Cost: 0.395    Valid Accuracy: 0.89
# Epoch: 164  - Cost: 0.394    Valid Accuracy: 0.89
# Epoch: 165  - Cost: 0.393    Valid Accuracy: 0.89
# Epoch: 166  - Cost: 0.392    Valid Accuracy: 0.891
# Epoch: 167  - Cost: 0.391    Valid Accuracy: 0.891
# Epoch: 168  - Cost: 0.39     Valid Accuracy: 0.891
# Epoch: 169  - Cost: 0.39     Valid Accuracy: 0.891
# Epoch: 170  - Cost: 0.389    Valid Accuracy: 0.891
# Epoch: 171  - Cost: 0.388    Valid Accuracy: 0.891
# Epoch: 172  - Cost: 0.387    Valid Accuracy: 0.891
# Epoch: 173  - Cost: 0.386    Valid Accuracy: 0.891
# Epoch: 174  - Cost: 0.386    Valid Accuracy: 0.891
# Epoch: 175  - Cost: 0.385    Valid Accuracy: 0.892
# Epoch: 176  - Cost: 0.384    Valid Accuracy: 0.892
# Epoch: 177  - Cost: 0.383    Valid Accuracy: 0.892
# Epoch: 178  - Cost: 0.383    Valid Accuracy: 0.892
# Epoch: 179  - Cost: 0.382    Valid Accuracy: 0.892
# Epoch: 180  - Cost: 0.381    Valid Accuracy: 0.892
# Epoch: 181  - Cost: 0.38     Valid Accuracy: 0.892
# Epoch: 182  - Cost: 0.38     Valid Accuracy: 0.892
# Epoch: 183  - Cost: 0.379    Valid Accuracy: 0.892
# Epoch: 184  - Cost: 0.378    Valid Accuracy: 0.893
# Epoch: 185  - Cost: 0.377    Valid Accuracy: 0.893
# Epoch: 186  - Cost: 0.377    Valid Accuracy: 0.893
# Epoch: 187  - Cost: 0.376    Valid Accuracy: 0.893
# Epoch: 188  - Cost: 0.375    Valid Accuracy: 0.894
# Epoch: 189  - Cost: 0.375    Valid Accuracy: 0.894
# Epoch: 190  - Cost: 0.374    Valid Accuracy: 0.894
# Epoch: 191  - Cost: 0.373    Valid Accuracy: 0.894
# Epoch: 192  - Cost: 0.373    Valid Accuracy: 0.894
# Epoch: 193  - Cost: 0.372    Valid Accuracy: 0.894
# Epoch: 194  - Cost: 0.371    Valid Accuracy: 0.894
# Epoch: 195  - Cost: 0.371    Valid Accuracy: 0.894
# Epoch: 196  - Cost: 0.37     Valid Accuracy: 0.894
# Epoch: 197  - Cost: 0.369    Valid Accuracy: 0.894
# Epoch: 198  - Cost: 0.369    Valid Accuracy: 0.894
# Epoch: 199  - Cost: 0.368    Valid Accuracy: 0.894
# Test Accuracy: 0.8878999948501587
